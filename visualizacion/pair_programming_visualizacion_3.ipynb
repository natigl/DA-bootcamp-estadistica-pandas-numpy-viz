# %% [markdown]
# ## Pair Programming Visualización III
# ---
#
#
# En este ejercicio, de nuevo, trabajaremos con el csv que generamos en el ejercicio de pair programming de Pandas V, ese en el que habíamos unido distintos csv en uno.
#
#
# En estos ejercicios aprenderemos a hacer algunas gráficas usando la librería seaborn. Igual que el ejercicio anterior de pair programming, para solucionar algunas preguntas tendréis que usar métodos y herramientas aprendidas anteriormente como groupby, value_counts, rename, filtrado de datos, etc.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **EJERCICIO 1**
#
# Usando la librería seaborn, crea una gráfica de barras que muestre el número de personas que han hecho cada actividad en cada año. Hacedlo solo desde el 2015. Os podrá salir una gráfica un poco fea, no os preocupeis, es lo que esperamos.

# %%
df= pd.read_csv('attacks5.csv')

# %%
df.head(1)
# Out:
#    Unnamed: 0 case_number    year        type     country      area location  \
# 0           0  1800.00.00  1800.0  Unprovoked  SEYCHELLES  St. Anne      NaN
#
#                           activity name sex_  age time species_  \
# 0  a corsair's boat was overturned  NaN    F  NaN  NaN      NaN
#
#                                                 href fatal_(y/n)  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...           Y
#
#                                      injury  date
# 0  FATAL, all onboard were killed by sharks  1800

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'case_number', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
#        'href', 'fatal_(y/n)', 'injury', 'date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1672 entries, 0 to 1671
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1672 non-null   int64
#  1   case_number  1672 non-null   object
#  2   year         1672 non-null   float64
#  3   type         1672 non-null   object
#  4   country      1662 non-null   object
#  5   area         1626 non-null   object
#  6   location     1621 non-null   object
#  7   activity     1641 non-null   object
#  8   name         1663 non-null   object
#  9   sex_         1658 non-null   object
#  10  age          1518 non-null   object
#  11  time         1512 non-null   object
#  12  species_     1546 non-null   object
#  13  href         1672 non-null   object
#  14  fatal_(y/n)  1585 non-null   object
#  15  injury       1664 non-null   object
#  16  date         1672 non-null   object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 222.2+ KB

# %%
df_2015 = df[df['year'] >= 2015]
df_2015.head(2)
# Out:
#      Unnamed: 0   case_number    year        type country        area  \
# 170           0    2018.06.25  2018.0     Boating     USA  California
# 171           1  2018.06.03.a  2018.0  Unprovoked  BRAZIL  Pernambuco
#
#                         location  activity                    name sex_ age  \
# 170  Oceanside, San Diego County  Paddling             Julie Wolfe    F  57
# 171        Piedade Beach, Recife  Swimming  Jose Ernesto da Silva     M  18
#
#                time     species_  \
# 170           18h00  White shark
# 171  Late afternoon  Tiger shark
#
#                                                   href fatal_(y/n)  \
# 170  http://sharkattackfile.net/spreadsheets/pdf_di...           N
# 171  http://sharkattackfile.net/spreadsheets/pdf_di...           Y
#
#                                                 injury         date
# 170  No injury to occupant, outrigger canoe and pad...  25-Jun-2018
# 171                                              FATAL  03-Jun-2018

# %%
plt.figure(figsize =(10,5))

# elegimos el método hisplot con la variable que queremos visualizar
fig = sns.histplot(x='activity', data = df_2015)

# establecemos el nombre de los ejes, pero recordad que esto no es obligatorio ya que Seaborn nos los genera automaticamente
fig.set(xlabel='Actividades', ylabel = 'Número')

# Ponemos título a  la gráfica
fig.set_title('Histograma de las actividades desde 2015' )
# mostramos la gráfica
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **EJERCICIO 2**
#
# Usando la librería seaborn, crea una gráfica de barras que muestre el número de ataques que han ocurrido cada año en función del sexo. Hacedlo solo desde el 2015.

# %%
'case_number', 'year', 'sex_'
# Out:
# ('case_number', 'year', 'sex_')

# %%
df_2015
# Out:
#      Unnamed: 0   case_number    year        type       country  \
# 170           0    2018.06.25  2018.0     Boating           USA
# 171           1  2018.06.03.a  2018.0  Unprovoked        BRAZIL
# 172           2  2018.05.26.b  2018.0  Unprovoked           USA
# 173           3    2018.05.24  2018.0    Provoked     AUSTRALIA
# 174           4  2018.05.13.a  2018.0     Invalid       ENGLAND
# ..          ...           ...     ...         ...           ...
# 317         147    2015.02.08  2015.0  Unprovoked     AUSTRALIA
# 318         148    2015.01.30  2015.0     Boating     AUSTRALIA
# 319         149    2015.01.27  2015.0    Provoked           USA
# 320         150    2015.01.06  2015.0  Unprovoked       BAHAMAS
# 321         151    2015.01.03  2015.0  Unprovoked  SOUTH AFRICA
#
#                       area                          location        activity  \
# 170             California       Oceanside, San Diego County        Paddling
# 171             Pernambuco             Piedade Beach, Recife        Swimming
# 172                Florida      Cocoa Beach, Brevard  County         Walking
# 173             Queensland                   Cairns Aquarium  Feeding sharks
# 174               Cornwall                    Off Land's End         Fishing
# ..                     ...                               ...             ...
# 317        New South Wales       Seven Mile Beach, Byron Bay         Surfing
# 318             Queensland  Nerang River, Surfer's  Paradise          Rowing
# 319                 Hawaii                           Lahaina   Shark fishing
# 320          Abaco Islands           Tahiti Beach, Elbow Cay      Snorkeling
# 321  Eastern Cape Province                Chintsa East Beach         Surfing
#
#                                      name sex_ age            time  \
# 170                           Julie Wolfe    F  57           18h00
# 171                Jose Ernesto da Silva     M  18  Late afternoon
# 172                             Cody High    M  15           17h00
# 173                                  male    M  32         Morning
# 174                          Max Berryman    M  21           08h15
# ..                                    ...  ...  ..             ...
# 317                         Jacob Reitman    M  35           06h45
# 318  Racing scull: Occupant Trevor Carter    M  57           05h00
# 319                       Michael Pollard    M  20           03h30
# 320                             Lacy Webb    F  34           16h00
# 321                          Jason Krafft    M  15           08h00
#
#                                   species_  \
# 170                            White shark
# 171                            Tiger shark
# 172                         Bull shark, 6'
# 173                        Grey reef shark
# 174                       Invalid incident
# ..                                     ...
# 317                      2 m to  3 m shark
# 318                      Bull shark, 1.3 m
# 319                               4' shark
# 320  White shark or oceanic whitetip shark
# 321               Raggedtooth shark, 1.3 m
#
#                                                   href fatal_(y/n)  \
# 170  http://sharkattackfile.net/spreadsheets/pdf_di...           N
# 171  http://sharkattackfile.net/spreadsheets/pdf_di...           Y
# 172  http://sharkattackfile.net/spreadsheets/pdf_di...           N
# 173  http://sharkattackfile.net/spreadsheets/pdf_di...           N
# 174  http://sharkattackfile.net/spreadsheets/pdf_di...           N
# ..                                                 ...         ...
# 317  http://sharkattackfile.net/spreadsheets/pdf_di...           N
# 318  http://sharkattackfile.net/spreadsheets/pdf_di...           N
# 319  http://sharkattackfile.net/spreadsheets/pdf_di...           N
# 320  http://sharkattackfile.net/spreadsheets/pdf_di...           N
# 321  http://sharkattackfile.net/spreadsheets/pdf_di...           N
#
#                                                 injury         date
# 170  No injury to occupant, outrigger canoe and pad...  25-Jun-2018
# 171                                              FATAL  03-Jun-2018
# 172                              Lower left leg bitten  26-May-2018
# 173  Minor bite to hand by captive shark. PROVOKED ...  24-May-2018
# 174  Injured by teeth of a dead porbeagle shark he ...  13-May-2018
# ..                                                 ...          ...
# 317  Laceration & puncture wounds to right flank & hip  08-Feb-2015
# 318            No injury, shark's teeth scratched hull  30-Jan-2015
# 319  Lacerations to calf by hooked shark PROVOKED I...  27-Jan-2015
# 320                         Severe bite to right flank  06-Jan-2015
# 321  Lacerations to lower left leg, puncture wounds...  03-Jan-2015
#
# [152 rows x 17 columns]

# %%
plt.figure(figsize =(10,5))

# elegimos el método hisplot con la variable que queremos visualizar
fig = sns.histplot(x='sex_', data = df_2015)

# establecemos el nombre de los ejes, pero recordad que esto no es obligatorio ya que Seaborn nos los genera automaticamente
fig.set(xlabel='Género', ylabel = 'Ataques')

# Ponemos título a  la gráfica
fig.set_title('Histograma de los ataques por sexo' )
# mostramos la gráfica
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **EJERCICIO 3**
#
# ¿Cuántos ataques hubo por año? Seleccionad solo desde el año 1500.

# %%
#filtramos desde el año 1500 
df_1500 = df[df['year'] >= 1500]
df_1500.head(2)
# Out:
#      Unnamed: 0   case_number    year        type country        area  \
# 170           0    2018.06.25  2018.0     Boating     USA  California
# 171           1  2018.06.03.a  2018.0  Unprovoked  BRAZIL  Pernambuco
#
#                         location  activity                    name sex_ age  \
# 170  Oceanside, San Diego County  Paddling             Julie Wolfe    F  57
# 171        Piedade Beach, Recife  Swimming  Jose Ernesto da Silva     M  18
#
#                time     species_  \
# 170           18h00  White shark
# 171  Late afternoon  Tiger shark
#
#                                                   href fatal_(y/n)  \
# 170  http://sharkattackfile.net/spreadsheets/pdf_di...           N
# 171  http://sharkattackfile.net/spreadsheets/pdf_di...           Y
#
#                                                 injury         date
# 170  No injury to occupant, outrigger canoe and pad...  25-Jun-2018
# 171                                              FATAL  03-Jun-2018

# %%
#groupby ataques/año?

# %%
# iniciamos la figura con un tamaño especifico
plt.figure(figsize =(8,4))

# iniciamos nuestra gráfica para contestar a la pregunta
fig = sns.countplot(x='case_number', data = df_1500)

# cambiamos el nombre de los ejes
fig.set(xlabel='año', ylabel= 'Ataques' )

# cambiamos el título de la gráfica
fig.set_title('Número de ataque por año')

# motramos la gráfica
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **EJERCICIO 4**
#
# Seleccionad solo los registros de USA, AUSTRALIA y SOUTH AFRICA. Muestra el número de ataques por país y año desde el año 1900.

# %% [markdown]
# ---

# %% [markdown]
# **EJERCICIO 5**
#
# Realizad un boxplot donde se muestre los principales estadísticos del número de ataques por país.

# %% [markdown]
# ---

# %% [markdown]
# 📌 NOTA Somos analistas y no nos vale con sacar las gráficas. Incluid una celda de markdown donde expliqueis que es lo que estamos viendo en las gráficas, es decir, haced una interpretación de los resultados.
