# %% [markdown]
# ### PAIR PROGRAMMING PANDAS VI
# ---

# %% [markdown]
# Es el momento de poner en práctica los groupby de pandas. Para esto vamos a trabajar con el csv creado en el ejercicio de pair programming anterior.
#
# El objetivo de este ejercicio es agrupar los datos para contestar las siguientes preguntas:

# %%
import pandas as pd

# %%
# Cargamos y abrimos el archivo del pair de ayer

df = pd.read_csv('attacks4.csv')
df.head(2)
# Out:
#    Unnamed: 0   case_number    year        type     country      area  \
# 0           0    1800.00.00  1800.0  Unprovoked  SEYCHELLES  St. Anne
# 1           1  1797.05.28.R  1797.0  Unprovoked         NaN       NaN
#
#   location                         activity   name sex_  age time species_  \
# 0      NaN  a corsair's boat was overturned    NaN    F  NaN  NaN      NaN
# 1      NaN                Dropped overboard  child  NaN  NaN  NaN      NaN
#
#                                                 href fatal_(y/n)  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...           Y
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...           Y
#
#                                      injury                  date
# 0  FATAL, all onboard were killed by sharks                  1800
# 1                                     FATAL  Reported May-28-1797

# %%
# Borramos la columna 'Unnamed:0' con el método .drop

df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head(2)
# Out:
#     case_number    year        type     country      area location  \
# 0    1800.00.00  1800.0  Unprovoked  SEYCHELLES  St. Anne      NaN
# 1  1797.05.28.R  1797.0  Unprovoked         NaN       NaN      NaN
#
#                           activity   name sex_  age time species_  \
# 0  a corsair's boat was overturned    NaN    F  NaN  NaN      NaN
# 1                Dropped overboard  child  NaN  NaN  NaN      NaN
#
#                                                 href fatal_(y/n)  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...           Y
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...           Y
#
#                                      injury                  date
# 0  FATAL, all onboard were killed by sharks                  1800
# 1                                     FATAL  Reported May-28-1797

# %%
# Comprobamos que la hemos eliminado

df.columns
# Out:
# Index(['case_number', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex_', 'age', 'time', 'species_', 'href',
#        'fatal_(y/n)', 'injury', 'date'],
#       dtype='object')

# %% [markdown]
# **EJERCICIO 1**
#
# ¿Cuántos ataques hubo por país? Devuelve un DataFrame.
# 📌 NOTA Ordena los resultados de mayor a menor. Esto todavía no lo hemos visto, pero un DataFrame lo podemos ordenar con .sort_values(). Aquí tenéis una explicación de cómo hacerlo.

# %%
# Agrupamos los ataques filtrando por la columna country y case_number, utilizando .count para 
# obtener la cantidad

df_paises = df.groupby('country')['case_number'].count()

# %%
# Utilizamos los paises como índice con el método .reset_index

df_paises.reset_index()
# Out:
#            country  case_number
# 0   AMERICAN SAMOA            2
# 1        ARGENTINA            1
# 2            ASIA?            1
# 3        AUSTRALIA          343
# 4          BAHAMAS           29
# ..             ...          ...
# 90         URUGUAY            2
# 91             USA          741
# 92         VANUATU            4
# 93       VENEZUELA            4
# 94         VIETNAM            5
#
# [95 rows x 2 columns]

# %%
# Ordenamos de mayor a menor con el método sort_values

df_paises.sort_values(axis=0, ascending=False, inplace=False,)
# Out:
# country
# USA             741
# AUSTRALIA       343
# SOUTH AFRICA    234
# BAHAMAS          29
# NEW ZEALAND      21
#                ...
# PHILIPPINES       1
# RED SEA?          1
# EL SALVADOR       1
# ROATAN            1
# LIBYA             1
# Name: case_number, Length: 95, dtype: int64

# %%
df_pais = df_paises.reset_index()
df_pais.head()
# Out:
#           country  case_number
# 0  AMERICAN SAMOA            2
# 1       ARGENTINA            1
# 2           ASIA?            1
# 3       AUSTRALIA          343
# 4         BAHAMAS           29

# %% [markdown]
# ---

# %% [markdown]
# **EJERCICIO 2**
#
# ¿Cuántos ataques ha habido por año? Devuelve un DataFrame. De nuevo ordena los resultados de mayor a menor.

# %%
df_años = df.groupby('year')['case_number'].agg(ataques=('count'))
df_años.reset_index()
df_años
# Out:
#         ataques
# year
# 0.0         125
# 5.0           1
# 77.0          1
# 500.0         1
# 1543.0        1
# ...         ...
# 2014.0       35
# 2015.0       68
# 2016.0       37
# 2017.0       30
# 2018.0       17
#
# [147 rows x 1 columns]

# %%
df_años.sort_values(by='ataques', ascending=False, inplace=False,)
df_años.reset_index()
# Out:
#        year  ataques
# 0       0.0      125
# 1       5.0        1
# 2      77.0        1
# 3     500.0        1
# 4    1543.0        1
# ..      ...      ...
# 142  2014.0       35
# 143  2015.0       68
# 144  2016.0       37
# 145  2017.0       30
# 146  2018.0       17
#
# [147 rows x 2 columns]

# %%
df_anyo= df_años.reset_index()

# %%
df_anyo.head()
# Out:
#      year  ataques
# 0     0.0      125
# 1     5.0        1
# 2    77.0        1
# 3   500.0        1
# 4  1543.0        1

# %% [markdown]
# ---

# %% [markdown]
# **EJERCICIO 3**
#
# ¿Cuántos ataques hubo por año y sexo? Devolved un DataFrame solo del año 2000 en adelante.

# %%
df.columns
# Out:
# Index(['case_number', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex_', 'age', 'time', 'species_', 'href',
#        'fatal_(y/n)', 'injury', 'date'],
#       dtype='object')

# %%
# Filtramos con la suma de los ataques por año y sexo

df_3 = df.groupby(['year', 'sex_'])['case_number'].agg(ataques=('count'))
df_3
# Out:
#              ataques
# year   sex_
# 0.0    F          13
#        M         104
# 5.0    M           1
# 77.0   M           1
# 500.0  M           1
# ...              ...
# 2016.0 M          30
# 2017.0 F           9
#        M          21
# 2018.0 F           2
#        M          15
#
# [196 rows x 1 columns]

# %%
df_3.reset_index()
# Out:
#        year sex_  ataques
# 0       0.0    F       13
# 1       0.0    M      104
# 2       5.0    M        1
# 3      77.0    M        1
# 4     500.0    M        1
# ..      ...  ...      ...
# 191  2016.0    M       30
# 192  2017.0    F        9
# 193  2017.0    M       21
# 194  2018.0    F        2
# 195  2018.0    M       15
#
# [196 rows x 3 columns]

# %%
# Volvemos a filtar por los que han sido a partir del año 2000

df_2000 = df_3[df_3['year'] >= 2000.0]
df_2000

# %% [markdown]
# ---

# %% [markdown]
# **EJERCICIO 4**
#
# Primero extraed solo las filas que correspondan a USA, AUSTRALIA y SOUTH AFRICA. ¿Cuántos de los ataques fueron letales por sexo? Devuelve un DataFrame.

# %%
# Agrupamos los ataques filtrando por los paises, utilizando el método isin para USA, AUSTRALIA Y SUDAFRICA 

df_4 = df[df['country'].isin(['USA','AUSTRALIA', 'SOUTH AFRICA'])]
df_4.head(2)
# Out:
#   case_number    year        type    country             area       location  \
# 3  1791.00.00  1791.0  Unprovoked  AUSTRALIA  New South Wales   Port Jackson
# 4  1788.05.10  1788.0        Boat  AUSTRALIA  New South Wales  Sydney Harbor
#
#   activity                              name sex_  age time species_  \
# 3      NaN  female, an Australian aboriginal    F  NaN  NaN      NaN
# 4  Fishing                              boat  NaN  NaN  NaN      NaN
#
#                                                 href fatal_(y/n)  \
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...           Y
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...           N
#
#                                              injury         date
# 3                            FATAL, "bitten in two"         1791
# 4  No injury to occupants, shark bit oar and rudder  10-May-1788

# %%
# Volvemos a filtrar el por los accidentes que han sido fatales(fatal=Y)

df_fatal = df_4[df_4['fatal_(y/n)']=='Y']
df_fatal.head(2)
# Out:
#    case_number    year        type    country             area  \
# 3   1791.00.00  1791.0  Unprovoked  AUSTRALIA  New South Wales
# 10  1780.08.08  1780.0  Unprovoked        USA          Florida
#
#                              location  activity  \
# 3                        Port Jackson       NaN
# 10  Pensacola Harbor, Escambia County  Swimming
#
#                                 name sex_  age time species_  \
# 3   female, an Australian aboriginal    F  NaN  NaN      NaN
# 10                      Joseph Feron    M  NaN  NaN      NaN
#
#                                                  href fatal_(y/n)  \
# 3   http://sharkattackfile.net/spreadsheets/pdf_di...           Y
# 10  http://sharkattackfile.net/spreadsheets/pdf_di...           Y
#
#                     injury         date
# 3   FATAL, "bitten in two"         1791
# 10                   FATAL  08-Aug-1780

# %% [markdown]
# ---

# %% [markdown]
# **EJERCICIO 5**
#
# Usando el DataFrame creado en el ejercicio anterior. ¿En qué país hubo más ataques?

# %%
# Agrupamos por país y contamos el número de casos, 
# USA fue donde hubo más ataques

df_4.groupby('country')['case_number'].count()
# Out:
# country
# AUSTRALIA       343
# SOUTH AFRICA    234
# USA             741
# Name: case_number, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# **EJERCICIO 6**
#
# ¿Qué y cuántos tipos de ataques hubo por país?

# %%
# Agrupamos el número de ataques por paises y tipo de ataque

df_pais_tipo = df.groupby(['country', 'type'])['case_number'].agg(ataques=('count')) 
df_pais_tipo = df_pais_tipo.reset_index()
df_pais_tipo
# Out:
#             country        type  ataques
# 0    AMERICAN SAMOA  Unprovoked        2
# 1         ARGENTINA  Unprovoked        1
# 2             ASIA?  Unprovoked        1
# 3         AUSTRALIA        Boat        1
# 4         AUSTRALIA     Boating        4
# ..              ...         ...      ...
# 131             USA  Unprovoked      632
# 132         VANUATU    Provoked        1
# 133         VANUATU  Unprovoked        3
# 134       VENEZUELA  Unprovoked        4
# 135         VIETNAM  Unprovoked        5
#
# [136 rows x 3 columns]
