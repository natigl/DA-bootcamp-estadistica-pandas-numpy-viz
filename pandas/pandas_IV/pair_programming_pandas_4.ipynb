# %% [markdown]
# ## PAIR PROGRAMMING PANDAS IV
# ---

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# **EJERCICIO 1**
#
# Cargad el csv que guardasteis ayer.
#
#
# Antes de seguir con las preguntas, este DataFrame está terriblemente sucio. En las próximas sesiones lo iremos limpiando.
#
#
# Para evitar posibles errores con los nulos vamos a eliminar todos los nulos del DataFrame.
#
#
# Para ello vamos a utilizar el método .dropna() de pandas. Tendréis que ejecutar la siguiente línea de código para eliminar los nulos del DataFrame y poder seguir haciendo el resto de los ejercicios.

# %%
# Cargamos el archivo
df_csv = pd.read_csv("attacks2.csv")

# %%
df_csv.shape
# Out:
# (6114, 14)

# %%
# Eliminamos los nulos con el método .dropna

df_csv.dropna(inplace = True)

# %%
df_csv.shape
# Out:
# (1502, 14)

# %% [markdown]
# - ¿Cuántas filas se han eliminado con esta línea de código?

# %%
filas_eliminadas = 6114 - 1502
f'El numero de filas eliminadas es {filas_eliminadas}'
# Out:
# 'El numero de filas eliminadas es 4612'

# %%
df_csv.columns
# Out:
# Index(['case_number', 'unnamed:_0', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
#        'href'],
#       dtype='object')

# %% [markdown]
# -------

# %% [markdown]
# **EJERCICIO 2**
#
# ¿Cuál es el número de ataques que se han producido en Estados Unidos?

# %%
# Filtramos en base al valor de la columna Country con la condición de que este sea USA. 
# Lo almacenamos en un nuevo DF y utilizando el metodo .shape para ver el numero de 
# registros / ataques, 719

df_estados_unidos = df_csv[df_csv["country"] == "USA"]
df_estados_unidos.shape
# Out:
# (719, 14)

# %% [markdown]
# ---

# %% [markdown]
# **EJERCICIO 3**
#
# ¿Cuál es el número de ataques que se han producido en España?

# %%
# Filtramos en base al valor de la columna Country con la condición de que este sea SPAIN. 
# Lo almacenamos en un nuevo DF y utilizando el metodo .shape para ver el numero de 
# registros / ataques, 5

df_españa = df_csv[df_csv["country"] == "SPAIN"]
df_españa.shape
# Out:
# (5, 14)

# %% [markdown]
# - ¿En qué regiones se han producido los ataques (columna location) ?

# %%
# Filtramos por columna location en el DF previamente almacenado con los resultados de España

ataques_location = df_españa["location"]
ataques_location
# Out:
# 98                     Grao de Moncofa
# 233                   Arenales del Sol
# 377           Poniente Beach, Benidorm
# 1007        Sardina del Norte, GÃ¡ldar
# 2469    Playa de las Arenas, Valencia
# Name: location, dtype: object

# %% [markdown]
# - ¿Cuántos ataques se han producido en cada área (columna area?

# %%
ataques_area = df_españa["area"].value_counts()
ataques_area
# Out:
# CastellÃ³n             1
# Alicante Province      1
# Alicante               1
# Grand Canary Island    1
# Costa Blanca           1
# Name: area, dtype: int64

# %% [markdown]
# -----

# %% [markdown]
# **EJERCICIO 4**
#
# Extraed un DataFrame nuevo con los ataques que se han producido en Australia y Estados Unidos.
#
# 📌 Nota Este ejercicio se puede resolver usando dos condiciones de filtrado o usando el método
# isin(). Hacedlo con ambas herramientas.

# %%
# Extraemos el DF filtrando en base al valor de una columna, pero pidiendo que se cumplan dos 
# condiciones distintas utilizando el operador OR | , ya que en este caso las condiciones no 
# se pueden cumplir a la vez 

ataques_aus_usa = df_csv[(df_csv["country"] == "AUSTRALIA") | (df_csv["country"] == "USA")]
ataques_aus_usa.head(2)
# Out:
#     case_number  unnamed:_0    year        type country        area  \
# 0    2018.06.25           0  2018.0     Boating     USA  California
# 8  2018.05.26.b           8  2018.0  Unprovoked     USA     Florida
#
#                        location  activity         name sex_ age   time  \
# 0   Oceanside, San Diego County  Paddling  Julie Wolfe    F  57  18h00
# 8  Cocoa Beach, Brevard  County   Walking    Cody High    M  15  17h00
#
#          species_                                               href  \
# 0     White shark  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  Bull shark, 6'  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#        siglo
# 0  siglo-XXI
# 8  siglo-XXI

# %%
# Extraemos el DF con el metodo isin() de pandas

ataques_isin = df_csv[df_csv["country"].isin(["USA","AUSTRALIA"])]
ataques_isin.head(2)
# Out:
#     case_number  unnamed:_0    year        type country        area  \
# 0    2018.06.25           0  2018.0     Boating     USA  California
# 8  2018.05.26.b           8  2018.0  Unprovoked     USA     Florida
#
#                        location  activity         name sex_ age   time  \
# 0   Oceanside, San Diego County  Paddling  Julie Wolfe    F  57  18h00
# 8  Cocoa Beach, Brevard  County   Walking    Cody High    M  15  17h00
#
#          species_                                               href  \
# 0     White shark  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  Bull shark, 6'  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#        siglo
# 0  siglo-XXI
# 8  siglo-XXI

# %% [markdown]
# - ¿Cuántos ataques se han producido en cada país?

# %%
ataques_isin['country'].value_counts()
# Out:
# USA          719
# AUSTRALIA    324
# Name: country, dtype: int64

# %% [markdown]
# - ¿Ha habido ataques en Australia a gente que estuviera remando (lo encontrareis como Paddling en el DataFrame en la columna activity)?

# %%
ataques_paddling = df_csv[(df_csv["activity"] == "Paddling") & (df_csv["country"] == "AUSTRALIA")]
ataques_paddling
# No devuelve ataques que cumplan las dos condiciones
# Out:
# Empty DataFrame
# Columns: [case_number, unnamed:_0, year, type, country, area, location, activity, name, sex_, age, time, species_, href, siglo]
# Index: []

# %% [markdown]
# -  ¿Cuántos ataques se han producido en Australia antes del 2000?

# %%
df_ataques_fecha = df_csv[(df_csv["year"] <= 2000.0) & (df_csv["country"] == "AUSTRALIA")]
df_ataques_fecha
# 157 ataques/rows en Australia antes del año 2000
# Out:
#        case_number  unnamed:_0    year        type    country  \
# 1979    2000.12.03        1986  2000.0  Unprovoked  AUSTRALIA
# 1985  2000.11.06.b        1992  2000.0  Unprovoked  AUSTRALIA
# 1986  2000.11.06.a        1993  2000.0  Unprovoked  AUSTRALIA
# 1997    2000.09.25        2004  2000.0  Unprovoked  AUSTRALIA
# 1998    2000.09.24        2005  2000.0  Unprovoked  AUSTRALIA
# ...            ...         ...     ...         ...        ...
# 5359    1912.01.26        5375  1912.0  Unprovoked  AUSTRALIA
# 5481    1905.03.26        5498  1905.0  Unprovoked  AUSTRALIA
# 5631    1894.11.28        5648  1894.0  Unprovoked  AUSTRALIA
# 5667    1892.03.02        5684  1892.0    Provoked  AUSTRALIA
# 5797    1880.11.25        5814  1880.0  Unprovoked  AUSTRALIA
#
#                    area                                        location  \
# 1979         Queensland                  Sykes Reef, Great Barrier Reef
# 1985  Western Australia                          Cottesloe Beach, Perth
# 1986  Western Australia                          Cottesloe Beach, Perth
# 1997    South Australia                     Black Point, Eyre Peninsula
# 1998    South Australia                        Cactus Beach near Penong
# ...                 ...                                             ...
# 5359    New South Wales  Fig Tree Bridge, Lane Cove River, near Sydney
# 5481    New South Wales                                         Lismore
# 5631    New South Wales                                      Newcastle
# 5667    New South Wales                                  Lake Macquarie
# 5797         Queensland                    Petrie Bight, Brisbane River
#
#           activity                 name sex_ age       time  \
# 1979  Spearfishing          Chris Hogan    M  38      09h30
# 1985      Swimming           Dirk Avery    M  52      06h30
# 1986      Swimming             Ken Crew    M  49      06h30
# 1997       Surfing         Jevan Wright    M  17      13h00
# 1998       Surfing        Cameron Bayes    M  25      07h30
# ...            ...                  ...  ...  ..        ...
# 5359      Swimming  James Edward Morgan    M  21      15h00
# 5481       Bathing         Richard Owen    M  40    Morning
# 5631       Bathing       Horace Hewison    M  19    Morning
# 5667       Fishing     Christopher Wang    M  21      Night
# 5797      Swimming         Alexey Drury    M  12  Afternoon
#
#                                                species_  \
# 1979                Bronze whaler shark, 2.5 m [8.25']
# 1985                          White shark, 4.9 m [16']
# 1986                          White shark, 5 m [16.5']
# 1997                                        White shark
# 1998            White shark, 4 m to 5 m [13' to 16.5']
# ...                                                 ...
# 5359  2.8 m [9'3"] whaler shark captured 3 days late...
# 5481                                           5' shark
# 5631                                   10' to 12' shark
# 5667                                          12' shark
# 5797                                         Bull shark
#
#                                                    href      siglo
# 1979  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 1985  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 1986  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 1997  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 1998  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# ...                                                 ...        ...
# 5359  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo-XX
# 5481  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo-XX
# 5631  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo-XX
# 5667  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo-XX
# 5797  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo-XX
#
# [157 rows x 15 columns]

# %% [markdown]
# -  ¿Y después del 2000?

# %%
df_ataques_fecha2 = df_csv[(df_csv["year"] > 2000.0) & (df_csv["country"] == "AUSTRALIA")]
df_ataques_fecha2
# 167 ataques/rows en Australia después del año 2000
# Out:
#        case_number  unnamed:_0    year        type    country  \
# 10      2018.05.24          10  2018.0    Provoked  AUSTRALIA
# 21    2018.04.25.a          21  2018.0  Unprovoked  AUSTRALIA
# 36      2018.03.14          36  2018.0  Unprovoked  AUSTRALIA
# 37    2018.03.09.b          37  2018.0  Unprovoked  AUSTRALIA
# 38    2018.03.09.a          38  2018.0  Unprovoked  AUSTRALIA
# ...            ...         ...     ...         ...        ...
# 1876    2002.02.07        1883  2002.0     Boating  AUSTRALIA
# 1877  2002.01.30.b        1884  2002.0  Unprovoked  AUSTRALIA
# 1888    2001.10.02        1895  2001.0  Unprovoked  AUSTRALIA
# 1961  2001.04.02.a        1968  2001.0  Unprovoked  AUSTRALIA
# 1969    2001.02.04        1976  2001.0  Unprovoked  AUSTRALIA
#
#                    area                       location        activity  \
# 10           Queensland                Cairns Aquarium  Feeding sharks
# 21    Western Australia        Surfers Point, Prevelly         Surfing
# 36    Western Australia                 Waterman's Bay          Wading
# 37             Victoria                          Lorne        Swimming
# 38             Victoria                       Winkipop         Surfing
# ...                 ...                            ...             ...
# 1876    New South Wales  Paramatta River (near Sydney)        Kayaking
# 1877    New South Wales      Just north of Fingal Spit         Surfing
# 1888         Queensland             200 miles offshore      Snorkeling
# 1961    New South Wales        Nambucca River Entrance         Surfing
# 1969    New South Wales                    Broome Head         Surfing
#
#                       name sex_ age            time  \
# 10                    male    M  32         Morning
# 21               Rob Bruce    M  60           09h30
# 36    Luke Guy & Finn Bald    M  10           17h35
# 37           Rob Crossland    M  69           15h30
# 38            Lachie Brown    M  18           07h30
# ...                    ...  ...  ..             ...
# 1876         Paul McNamara    M  35           19h15
# 1877          Andrew Cribb    M  20  20h45 (Sunset)
# 1888       Katherine Jones    F  20           13h00
# 1961         Richard Ellis    M  40           10h00
# 1969           Mark Butler    M  40           16h15
#
#                                            species_  \
# 10                                  Grey reef shark
# 21                                        3 m shark
# 36                                  Wobbegong shark
# 37                                      3.5 m shark
# 38                                      1.8 m shark
# ...                                             ...
# 1876  C. leucas tooth fragment recovered from kayak
# 1877                         Tiger shark, 3 m [10']
# 1888                           Bronze whaler shark?
# 1961                            Bronze whaler shark
# 1969          Bronze whaler shark, 2.5 m [8.25']  k
#
#                                                    href
# 10    http://sharkattackfile.net/spreadsheets/pdf_di...
# 21    http://sharkattackfile.net/spreadsheets/pdf_di...
# 36    http://sharkattackfile.net/spreadsheets/pdf_di...
# 37    http://sharkattackfile.net/spreadsheets/pdf_di...
# 38    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 1876  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1877  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1888  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1961  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1969  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [167 rows x 14 columns]

# %% [markdown]
# ------------

# %% [markdown]
# **EJERCICIO 5**
#
# Extraed unicamente los ataques a mujeres.

# %%
df_ataques_mujeres = df_csv[(df_csv["sex_"] == 'F') & (df_csv["country"] == "AUSTRALIA")]
df_ataques_mujeres.shape
# 31 registros/ataques a mujeres en Australia
# Out:
# (31, 14)

# %% [markdown]
# ---------------

# %% [markdown]
# **EJERCICIO 6**
#
# ¿Cuántas mujeres fueron atacadas en España?

# %%
df_ataques_mujeres2 = df_csv[(df_csv["sex_"] == 'F') & (df_csv["country"] == "SPAIN")]
df_ataques_mujeres2.shape
# 1 registro/ataque a mujeres en España
# Out:
# (1, 14)

# %% [markdown]
# ----------------

# %% [markdown]
# **EJERCICIO 7**
#
# Extraed los ataques que se hayan producido en el año 2000, 1997 y 2006. Utilizad el método isin() para resolver este ejercicio.

# %%
ataques_años= df_csv[df_csv['year'].isin([2000.0, 1997.0,2006.0])]
ataques_años['year'].value_counts()
# Out:
# 2006.0    40
# 2000.0    33
# 1997.0    19
# Name: year, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# **EJERCICIO 8**
#
# Si extraemos los valores únicos de la columna species nos podemos dar cuenta que está un poco sucia y extraer informacion útil de la misma se puede convertir en algo difícil. En este ejercicio tendréis que extraer los ataques que han ocurrido por tiburón blanco (lo encontraremos en la columna species como algo que contenga white o White). Usad el método str.contains() para resolver este ejercicio.

# %%
#patron = '^w\w+' #con este patron regex filtramos por palabras que empiecen por w y sigan con más letras

# %%
patron2 = '.+white.+' #con este patrón regex filtramos por la palabra white

# %%
df_csv.columns
# Out:
# Index(['case_number', 'unnamed:_0', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
#        'href'],
#       dtype='object')

# %%
tiburon_blanco= df_csv[df_csv["species_"].str.contains(patron2, case = False, regex=True)]
tiburon_blanco
# 254 ataques de tiburón blanco en todo el mundo
# Out:
#        case_number  unnamed:_0    year        type       country  \
# 0       2018.06.25           0  2018.0     Boating           USA
# 6     2018.06.03.a           6  2018.0  Unprovoked        BRAZIL
# 18    2018.04.28.b          18  2018.0  Unprovoked    COSTA RICA
# 23      2018.04.23          23  2018.0  Unprovoked      MALDIVES
# 24      2018.04.22          24  2018.0  Unprovoked  SOUTH AFRICA
# ...            ...         ...     ...         ...           ...
# 5212    1922.05.06        5225  1922.0  Unprovoked  SOUTH AFRICA
# 5216    1922.03.02        5229  1922.0  Unprovoked     AUSTRALIA
# 5218    1922.02.04        5231  1922.0  Unprovoked     AUSTRALIA
# 5297    1916.07.01        5311  1916.0  Unprovoked           USA
# 5528    1901.07.30        5545  1901.0  Unprovoked  SOUTH AFRICA
#
#                        area                        location  \
# 0                California     Oceanside, San Diego County
# 6                Pernambuco           Piedade Beach, Recife
# 18             Cocos Island                       Manuelita
# 23        Alifu Alifu Atoll                       Madoogali
# 24    Western Cape Province  Robberg Beach, Plettenberg Bay
# ...                     ...                             ...
# 5212  Western Cape Province        SimonÂs Town, False Bay
# 5216        New South Wales                          Coogee
# 5218        New South Wales                         Coogee
# 5297             New Jersey       Beach Haven, Ocean County
# 5528  Western Cape Province                  Windmill Beach
#
#                         activity  \
# 0                       Paddling
# 6                       Swimming
# 18                  Scuba diving
# 23                       Fishing
# 24                 Paddle-skiing
# ...                          ...
# 5212                    Swimming
# 5216  Bathing in knee-deep water
# 5218                    Swimming
# 5297                    Swimming
# 5528                    Swimming
#
#                                                   name sex_ age  \
# 0                                          Julie Wolfe    F  57
# 6                               Jose Ernesto da Silva     M  18
# 18                                                male    M  30
# 23                                       Ahmed Rasheed    M  32
# 24                                                male    M  33
# ...                                                ...  ...  ..
# 5212                                   Edward G. Pells    M  18
# 5216                                     Mervyn Gannon    M  21
# 5218                                   Milton Coughlan    M  18
# 5297                                Charles E. Vansant    M  24
# 5528  John Hendrick Adrian Chandler, a prisoner of war    M  29
#
#                 time                                           species_  \
# 0              18h00                                        White shark
# 6     Late afternoon                                        Tiger shark
# 18             10h40                                        Tiger shark
# 23             21h50                                        Tiger shark
# 24             09h40                                 White shark, 2.5 m
# ...              ...                                                ...
# 5212            A.M.  White shark, 12', identity confirmed by tooth ...
# 5216           11h00                           White shark, 2.4 m [8']
# 5218           15h30                                        White shark
# 5297           17h00      Thought to involve a 2.6 m [8.5'] white shark
# 5528           14h15                                        White shark
#
#                                                    href      siglo
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 6     http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 18    http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 23    http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 24    http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# ...                                                 ...        ...
# 5212  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo-XX
# 5216  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo-XX
# 5218  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo-XX
# 5297  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo-XX
# 5528  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo-XX
#
# [413 rows x 15 columns]

# %% [markdown]
# ---

# %% [markdown]
# **EJERCICIO 9**
#
# Extraed ahora los ataques por tiburón blanco o tigre. Utilizad el método str.contains() para resolver este ejercicio.

# %%
# patron3 = '^[w|t]\w+' #con este patron regex filtramos por palabras que empiecen por w ó t 
#y sigan con más letras

# %%
patron4 = '.+white.+|.+tiger.+'

# %%
tiburones = df_csv[df_csv["species_"].str.contains(patron4, case = False, regex=True)]
tiburones
# Out:
#        case_number  unnamed:_0    year        type           country  \
# 40      2018.02.23          40  2018.0  Unprovoked         AUSTRALIA
# 406   2015.06.24.b         407  2015.0  Unprovoked               USA
# 459     2015.01.06         460  2015.0  Unprovoked           BAHAMAS
# 495   2014.10.02.a         496  2014.0  Unprovoked         AUSTRALIA
# 553     2014.05.14         555  2014.0  Unprovoked         AUSTRALIA
# ...            ...         ...     ...         ...               ...
# 4210    1956.12.26        4222  1956.0  Unprovoked  PAPUA NEW GUINEA
# 4292    1955.02.05        4304  1955.0  Unprovoked         AUSTRALIA
# 5134    1926.07.23        5146  1926.0  Unprovoked             ITALY
# 5136    1926.07.08        5148  1926.0  Unprovoked               USA
# 5297    1916.07.01        5311  1916.0  Unprovoked               USA
#
#                                      area  \
# 40                        New South Wales
# 406                        North Carolina
# 459                         Abaco Islands
# 495                     Western Australia
# 553                       South Australia
# ...                                   ...
# 4210                   Milne Bay Province
# 4292                      New South Wales
# 5134  Golfo di Genova in the Ligurian Sea
# 5136                           California
# 5297                           New Jersey
#
#                                                location  \
# 40                   Little Congwong Beach, La Perouse
# 406                                           Surf City
# 459                             Tahiti Beach, Elbow Cay
# 495                 Kelpids Beach, Wylie Bay, Esperance
# 553                            Elliston, Eyre Peninsula
# ...                                                 ...
# 4210                         Samarai Island (south end)
# 4292               Sugarloaf Bay, Middle Harbor, Sydney
# 5134                                            Varazze
# 5136  San Francisco Bay (or San Leandro Bay), near c...
# 5297                          Beach Haven, Ocean County
#
#                                     activity                       name sex_  \
# 40                                  Swimming             Anna Shurapey     F
# 406                                 Swimming                Brady Noyes    M
# 459                               Snorkeling                  Lacy Webb    F
# 495                                  Surfing               Sean Pollard    M
# 553                                  Surfing              Andrew McLeod    M
# ...                                      ...                        ...  ...
# 4210                            Spearfishing  Patterson (John) Nikuniko    M
# 4292                                Swimming  Bruno Aloysius Rautenberg    M
# 5134                                Swimming          Augusto Casellato    M
# 5136  Swimming with dog near canning factory            Norman Piexotto    M
# 5297                                Swimming         Charles E. Vansant    M
#
#      age         time                                           species_  \
# 40    55  19h00, Dusk                Juvenile white shark,  2.7 to 3.2 m
# 406    6        12h25                                    Sandtiger shark
# 459   34        16h00              White shark or oceanic whitetip shark
# 495   23        11h00                          2 white shark: 13' & 9"8"
# 553   35        09h30                                  white shark, 15'
# ...   ..          ...                                                ...
# 4210  19        13h00  2.4 m [8'] tiger shark caught 40 hours later w...
# 4292  25        14h35             3.6 m  white shark  (or bronze whaler)
# 5134  20        11h00  Said to involve 6 to 7 m [20' to 23'] white shark
# 5136  15                       1.5 m [5'] white shark or sevengill shark
# 5297  24        17h00      Thought to involve a 2.6 m [8.5'] white shark
#
#                                                    href      siglo
# 40    http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 406   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 459   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 495   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 553   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# ...                                                 ...        ...
# 4210  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo-XX
# 4292  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo-XX
# 5134  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo-XX
# 5136  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo-XX
# 5297  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo-XX
#
# [159 rows x 15 columns]

# %% [markdown]
# ---

# %% [markdown]
# ** EJERCICIO 10**
#
# Utilizando la columna de year cread una nueva columna llamada siglo que tiene siglo-XX o siglo-XXI. Donde el año sea menor que 2000 pondremos siglo-XX y el resto de los años siglo-XXI.

# %%
# Utilizamos el método np.select, pasando las condiciones para separar por los años y creando las 
# opciones con los siglos.

años = [df_csv["year"] < 2000.0, df_csv["year"] >= 2000.0] 
siglos = ["siglo-XX", "siglo-XXI"] 

df_csv['siglo']= np.select(años, siglos)
df_csv.head()
# Out:
#      case_number  unnamed:_0    year        type    country        area  \
# 0     2018.06.25           0  2018.0     Boating        USA  California
# 6   2018.06.03.a           6  2018.0  Unprovoked     BRAZIL  Pernambuco
# 8   2018.05.26.b           8  2018.0  Unprovoked        USA     Florida
# 10    2018.05.24          10  2018.0    Provoked  AUSTRALIA  Queensland
# 13  2018.05.13.a          13  2018.0     Invalid    ENGLAND    Cornwall
#
#                         location        activity                    name sex_  \
# 0    Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 6          Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 8   Cocoa Beach, Brevard  County         Walking               Cody High    M
# 10               Cairns Aquarium  Feeding sharks                    male    M
# 13                Off Land's End         Fishing            Max Berryman    M
#
#    age            time          species_  \
# 0   57           18h00       White shark
# 6   18  Late afternoon       Tiger shark
# 8   15           17h00    Bull shark, 6'
# 10  32         Morning   Grey reef shark
# 13  21           08h15  Invalid incident
#
#                                                  href      siglo
# 0   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 6   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 8   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 10  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
# 13  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI

# %% [markdown]
# ---

# %% [markdown]
# **EJERCICIO 11**
#
# Guardad como un archivo csv nuevo. Lo usaremos en el pair programming de mañana.

# %%
# Guardamos el archivo en la carpeta del pair de hoy

df_csv.to_csv("attacks3.csv")

# %%
# Guardamos el archivo en la carpeta del pair de mañana

df_csv.to_csv("../pandas_V/attacks3.csv")
